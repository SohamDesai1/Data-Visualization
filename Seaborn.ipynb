# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
# %matplotlib inline

# %%
df = yf.download('AAPL', start='2022-01-01', end='2022-12-31', progress=False)
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  177.830002  182.880005  177.710007  182.009995  180.959732
# 2022-01-04  182.630005  182.940002  179.119995  179.699997  178.663071
# 2022-01-05  179.610001  180.169998  174.639999  174.919998  173.910660
# 2022-01-06  172.699997  175.300003  171.639999  172.000000  171.007507
# 2022-01-07  172.889999  174.139999  171.029999  172.169998  171.176514
#
#                Volume
# Date
# 2022-01-03  104487900
# 2022-01-04   99310400
# 2022-01-05   94537600
# 2022-01-06   96904000
# 2022-01-07   86709100

# %%
res = sns.lineplot(x=df.index, y=df['Close'])
res.set_title('AAPL Stock Price')
res.set_ylabel('Price')
res.set_xlabel('Date')
plt.show()

# %%
res = sns.barplot(x=df.index, y=df['Close'],color='red')
plt.show()

# %%
res = sns.barplot(x=df.index, y=df['Close'],palette='Blues')
plt.show()

# %%
sns.countplot(x='Close', data=df)
sns.countplot(x='Close', data=df,palette='Set2')
plt.show()

# %%
sns.countplot(y='Close', data=df)
plt.show()

# %%
sns.displot(df['Close'], kde=True)
plt.show()

# %%
sns.heatmap(df.corr(),cbar=True ,annot=True)
# Out:
# <AxesSubplot: >

# %%
sns.scatterplot(x='Close', y='Open', data=df,hue='Close')
plt.show()

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue='Close', palette='husl')

# %%
sns.lmplot(x='Close', y='Open', data=df, hue='Close', palette='husl')

# %%
sns.boxplot(x='Close', y='Open', data=df, hue='Close', palette='husl')
# Out:
# <AxesSubplot: xlabel='Close', ylabel='Open'>
